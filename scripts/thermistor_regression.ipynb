# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# %%
df = pd.read_excel("./thermistor.xlsx")
display(df)
# Out:
#       T     coeff         R
# 0   -40  43.10000  431000.0
# 1   -35  30.45000  304500.0
# 2   -30  21.76000  217600.0
# 3   -25  15.73000  157300.0
# 4   -20  11.48000  114800.0
# 5   -15   8.46600   84660.0
# 6   -10   6.30000   63000.0
# 7    -5   4.73000   47300.0
# 8     0   3.58200   35820.0
# 9     5   2.73400   27340.0
# 10   10   2.10200   21020.0
# 11   15   1.62900   16290.0
# 12   20   1.27200   12720.0
# 13   25   1.00000   10000.0
# 14   30   0.79210    7921.0
# 15   35   0.63150    6315.0
# 16   40   0.50670    5067.0
# 17   45   0.40900    4090.0
# 18   50   0.33190    3319.0
# 19   55   0.27090    2709.0
# 20   60   0.22220    2222.0
# 21   65   0.18320    1832.0
# 22   70   0.15180    1518.0
# 23   75   0.12640    1264.0
# 24   80   0.10570    1057.0
# 25   85   0.08873     887.3
# 26   90   0.07468     746.8
# 27   95   0.06307     630.7
# 28  100   0.05353     535.3
# 29  105   0.04568     456.8
# 30  110   0.03918     391.8
# 31  115   0.03374     337.4
# 32  120   0.02916     291.6
# 33  125   0.02527     252.7

# %%
# %matplotlib widget

R = df["R"].to_numpy()
T = df["T"].to_numpy()

coeffs = np.polyfit(R, T, 15)
coeffs = np.flip(coeffs)
display(coeffs)

def reg_eq(r):
    ret = 0
    for i, c in enumerate(coeffs):
        ret += c*(r**i)
    return ret

plt.close()
plt.scatter(R, T)
plt.plot(R, [reg_eq(r) for r in R])
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3340: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([ 1.26667113e+02, -4.94221074e-02,  1.09519117e-05, -1.27781356e-09,
#         8.44104863e-14, -3.36893986e-18,  8.44233082e-23, -1.34846038e-27,
#         1.36025164e-32, -8.27619691e-38,  2.64031523e-43, -1.98711870e-49,
#        -9.74006422e-55,  9.63875219e-61,  5.32852253e-66, -8.41079089e-72])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
